# %%
import pandas as pd

routes = pd.read_csv("sweeden_data/routes.txt", dtype=str)

routes.head(10)
# Out:
#            route_id          agency_id route_short_name route_long_name  \
# 0  9011001000100000  14010000000001001                1             NaN
# 1  9011001000200000  14010000000001001                2             NaN
# 2  9011001000300000  14010000000001001                3             NaN
# 3  9011001000400000  14010000000001001                4             NaN
# 4  9011001000500000  14010000000001001                5             NaN
# 5  9011001000600000  14010000000001001                6             NaN
# 6  9011001000700000  14010000000001001                7    Spårväg city
# 7  9011001001000000  14010000000001001               10      Blå linjen
# 8  9011001001100000  14010000000001001               11      Blå linjen
# 9  9011001001200000  14010000000001001               12    Nockebybanan
#
#   route_type              route_desc
# 0        700                 blåbuss
# 1        700                 blåbuss
# 2        700                 blåbuss
# 3        700                 blåbuss
# 4        700                 blåbuss
# 5        700                 blåbuss
# 6        900            Spårväg City
# 7        401  tunnelbanans blå linje
# 8        401  tunnelbanans blå linje
# 9        900            Nockebybanan

# %%
routes[routes["route_id"] == "9011001075800000"]
# Out:
#              route_id          agency_id route_short_name route_long_name  \
# 449  9011001075800000  14010000000001001              758             NaN
#
#     route_type route_desc
# 449        700        NaN

# %%
trips = pd.read_csv("sweeden_data/trips.txt", dtype=str)

trips.head(10)
# Out:
#            route_id service_id            trip_id trip_headsign direction_id  \
# 0  9011001000100000          1  14010100704898439           NaN            1
# 1  9011001000100000          2  14010100708559249           NaN            1
# 2  9011001000100000          3  14010200664345127           NaN            1
# 3  9011001000100000          1  14010200669010872           NaN            1
# 4  9011001000100000          4  14010100702335572           NaN            1
# 5  9011001000100000          1  14010100702343409           NaN            1
# 6  9011001000100000          2  14010100702359737           NaN            1
# 7  9011001000100000          5  14010100698533064           NaN            1
# 8  9011001000100000          6  14010100664373192           NaN            1
# 9  9011001000100000          7  14010100669010971           NaN            1
#
#               shape_id
# 0  1014010000482329256
# 1  1014010000482329256
# 2  1014010000482329256
# 3  1014010000482329256
# 4  1014010000482329256
# 5  1014010000482329256
# 6  1014010000482329256
# 7  1014010000482329256
# 8  1014010000482329256
# 9  1014010000482329256

# %%
trips[trips["trip_id"] == "14010000549855266"]
# Out:
#                route_id service_id            trip_id trip_headsign  \
# 90383  9011001075800000         50  14010000549855266           NaN
#
#       direction_id             shape_id
# 90383            0  1014010000527068180

# %%
stops = pd.read_csv("sweeden_data/stops.txt", dtype=str)

stops.head(100)
# Out:
#              stop_id        stop_name   stop_lat   stop_lon location_type  \
# 0   9021001000101000         Stavsnäs  59.286405  18.704700             1
# 1   9021001000102000         Styrsvik  59.280184  18.731426             1
# 2   9021001000103000        Nämdöböte  59.208731  18.740060             1
# 3   9021001000104000             Aspö  59.215843  18.753410             1
# 4   9021001000105000          Idöborg  59.204309  18.757769             1
# ..               ...              ...        ...        ...           ...
# 95  9021001000209000           Dalarö  59.129570  18.405221             1
# 96  9021001000210000        Jutholmen  59.125238  18.409336             1
# 97  9021001000211000             Aspö  59.117134  18.411589             1
# 98  9021001000212000  Stora Segholmen  59.113649  18.412886             1
# 99  9021001000213000     Dalarö skans  59.113292  18.391527             1
#
#    parent_station platform_code
# 0             NaN           NaN
# 1             NaN           NaN
# 2             NaN           NaN
# 3             NaN           NaN
# 4             NaN           NaN
# ..            ...           ...
# 95            NaN           NaN
# 96            NaN           NaN
# 97            NaN           NaN
# 98            NaN           NaN
# 99            NaN           NaN
#
# [100 rows x 7 columns]

# %%
# A prendre quand j'aurais la ligne idéale
shapes = pd.read_csv("sweeden_data/shapes.txt", dtype=str)
# trop lourd pour git
shapes.head(10)
# Out:
#               shape_id shape_pt_lat shape_pt_lon shape_pt_sequence  \
# 0  1014010000482329256    59.341873    18.118316                 1
# 1  1014010000482329256    59.341853    18.118402                 2
# 2  1014010000482329256    59.341754    18.118334                 3
# 3  1014010000482329256    59.341259    18.118047                 4
# 4  1014010000482329256    59.340929    18.116765                 5
# 5  1014010000482329256    59.340944    18.116478                 6
# 6  1014010000482329256    59.340571    18.115033                 7
# 7  1014010000482329256    59.340453    18.114870                 8
# 8  1014010000482329256    59.340353    18.114259                 9
# 9  1014010000482329256    59.341099    18.113851                10
#
#   shape_dist_traveled
# 0                   0
# 1                0.01
# 2                  12
# 3                  69
# 4                 151
# 5                 167
# 6                 259
# 7                 276
# 8                 312
# 9              397.99

# %%
agency = pd.read_csv("sweeden_data/agency.txt", dtype=str)

agency.head(10)
# Out:
#            agency_id                    agency_name                agency_url  \
# 0  14010000000001001  AB Storstockholms Lokaltrafik            https://sl.se/
# 1  14010000000001917           Upplands lokaltrafik  https://www.resrobot.se/
# 2  14010000000001939          Länstrafiken Sörmland  https://www.resrobot.se/
# 3  14010000000001961               AB SL Kundtjänst  https://www.resrobot.se/
# 4  14010000000001983      Kommuner i Stockholms Län  https://www.resrobot.se/
# 5  14010000000002005              Färdtjänstnämnden  https://www.resrobot.se/
# 6  14010000000002027     Vägverket Färjerederiet AB  https://www.resrobot.se/
# 7  14010000000002049         People Travel Group AB  https://www.resrobot.se/
# 8  14010000000002071  Waxholmsbolaget Ångfartygs AB  https://www.resrobot.se/
# 9  14010000000002093                          SJ AB  https://www.resrobot.se/
#
#     agency_timezone agency_lang agency_fare_url
# 0  Europe/Stockholm          sv  https://sl.se/
# 1  Europe/Stockholm          sv             NaN
# 2  Europe/Stockholm          sv             NaN
# 3  Europe/Stockholm          sv             NaN
# 4  Europe/Stockholm          sv             NaN
# 5  Europe/Stockholm          sv             NaN
# 6  Europe/Stockholm          sv             NaN
# 7  Europe/Stockholm          sv             NaN
# 8  Europe/Stockholm          sv             NaN
# 9  Europe/Stockholm          sv             NaN

# %%
bus_routes = routes[routes["route_type"] == "700"]
bus_routes.head(10)
# Out:
#             route_id          agency_id route_short_name route_long_name  \
# 0   9011001000100000  14010000000001001                1             NaN
# 1   9011001000200000  14010000000001001                2             NaN
# 2   9011001000300000  14010000000001001                3             NaN
# 3   9011001000400000  14010000000001001                4             NaN
# 4   9011001000500000  14010000000001001                5             NaN
# 5   9011001000600000  14010000000001001                6             NaN
# 30  9011001005000000  14010000000001001               50             NaN
# 31  9011001005300000  14010000000001001               53             NaN
# 32  9011001005400000  14010000000001001               54             NaN
# 33  9011001005500000  14010000000001001               55             NaN
#
#    route_type route_desc
# 0         700    blåbuss
# 1         700    blåbuss
# 2         700    blåbuss
# 3         700    blåbuss
# 4         700    blåbuss
# 5         700    blåbuss
# 30        700        NaN
# 31        700        NaN
# 32        700        NaN
# 33        700        NaN

# %%
bus_routes_test = bus_routes[bus_routes['route_long_name'].notna()]

bus_routes_test.head()
# Out:
#              route_id          agency_id route_short_name  \
# 538  9011001091200000  14010000000001001               12
# 539  9011001092000000  14010000000001001              21B
# 542  9011001092500000  14010000000001001              25M
# 543  9011001092600000  14010000000001001              26M
# 544  9011001093000000  14010000000001001               30
#
#            route_long_name route_type       route_desc
# 538  Ersätter Nockebybanan        700  Ersättningsbuss
# 539  Ersätter Lidingöbanan        700  Ersättningsbuss
# 542  Ersätter Saltsjöbanan        700  Ersättningsbuss
# 543  Ersätter Saltsjöbanan        700  Ersättningsbuss
# 544     Ersätter Tvärbanan        700  Ersättningsbuss
