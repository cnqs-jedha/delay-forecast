# %%
import pandas as pd
import requests
import json
import os
import io
import py7zr
import zipfile
import csv
import tempfile
from datetime import datetime
from pathlib import Path
from itertools import islice
from collections import defaultdict
from dotenv import load_dotenv
import shutil
import copy
from google.transit import gtfs_realtime_pb2
from google.protobuf.message import DecodeError
import logging

load_dotenv()
# Out:
# True

# %%
KODA_KEY = os.getenv("API_KODA_KEY")
GTFS_RT_KEY = os.getenv("API_GTFS_RT_KEY")  # clé GTFS Regional Realtime

# %%
#host_api = "https://api.koda.trafiklab.se/KoDa/api/v2"

#base_history = "gtfs-rt"
#base_reference = "gtfs-static"

#operator = "sl"

#type_of_api = "TripUpdates"

#url_history = host_api + base_history + operator + type_of_api
#url_reference = host_api + base_reference + operator

#call_date = "2025-03-15"

#params = {
 #   "date": call_date, 
 #   "key": KODA_KEY
#}

# %%
def call_koda_api(base_url, date, operator = "sl", endpoint=""):
    if endpoint != "":
        api_url = f"https://api.koda.trafiklab.se/KoDa/api/v2/{base_url}/{operator}/{endpoint}"
    else:
        api_url = f"https://api.koda.trafiklab.se/KoDa/api/v2/{base_url}/{operator}"
        
    params = {
        "date": date, 
        "key": KODA_KEY
    }
    
    request = requests.get(f"{api_url}", params=params, timeout=20)
    print(api_url)
    print(request)
    print(len(request.content), "BYTES")

    return request

def call_koda_history_api(date):
    request = call_koda_api("gtfs-rt", date, endpoint="TripUpdates")
    return request

def call_koda_reference_api(date):
    request = call_koda_api("gtfs-static", date)
    return request

# %%
r_history = call_koda_history_api("2025-03-15")
# Out:
# https://api.koda.trafiklab.se/KoDa/api/v2/gtfs-rt/sl/TripUpdates
# <Response [200]>
# 41448769 BYTES

# %%
r_reference = call_koda_reference_api("2025-03-15")
# Out:
# https://api.koda.trafiklab.se/KoDa/api/v2/gtfs-static/sl
# <Response [200]>
# 52438156 BYTES

# %%
def read_koda_history_day(request, items_by_batch=400):
    logging.basicConfig(
        level=logging.INFO,
        format="%(asctime)s | %(levelname)s | %(message)s",
        datefmt="%H:%M:%S"
    )

    logger = logging.getLogger("gtfs")

    archive_bytes = io.BytesIO(request.content)
    
    # FICHIER TEMPORAIRES
    tmpdir = tempfile.mkdtemp(prefix="koda_")
    tmp = Path(tmpdir)

    history_entities = []
    bad_files = []

    BATCH = items_by_batch

    feed = gtfs_realtime_pb2.FeedMessage()

    # 1) liste des candidats
    archive_bytes.seek(0)
    with py7zr.SevenZipFile(archive_bytes, mode="r") as z:
        candidates = [n for n in z.getnames() if n.lower().endswith(".pb")]

    print("Nb fichiers .pb:", len(candidates))

    # 2) extraction + parse par batch
    for i in range(0, len(candidates), BATCH):
        batch = candidates[i:i+BATCH]

        logger.info(
            "Batch %d–%d / %d (%.1f%%)",
            i + 1,
            min(i + BATCH, len(candidates)),
            len(candidates),
            100 * (i + len(batch)) / len(candidates)
        )

        try:
            archive_bytes.seek(0)
            with py7zr.SevenZipFile(archive_bytes, mode="r") as z:
                z.extract(path=tmpdir, targets=batch)
        except Exception as e:
            # si un batch plante, on retombe en mode "un par un" juste pour ce batch
            for name in batch:
                try:
                    archive_bytes.seek(0)
                    with py7zr.SevenZipFile(archive_bytes, mode="r") as z:
                        z.extract(path=tmpdir, targets=[name])
                except Exception as e2:
                    bad_files.append((name, f"ExtractError: {e2!r}"))
            continue

        for name in batch:
            p = tmp / name
            try:
                raw = p.read_bytes()
                feed.Clear()
                try:
                    feed.ParseFromString(raw)
                except DecodeError as de:
                    bad_files.append((name, f"DecodeError: {de!r}"))
                    continue

                for entity in feed.entity:
                    history_entities.append(copy.deepcopy(entity))

            except Exception as e:
                bad_files.append((name, f"Read/ParseError: {e!r}"))
            finally:
                p.unlink(missing_ok=True)

    shutil.rmtree(tmpdir, ignore_errors=True)

    print("✅ Total entités enregistrées:", len(history_entities))
    print("⚠️ Fichiers ignorés:", len(bad_files))
    print("Exemples:", bad_files[:5])

    return history_entities, bad_files

# %%
history_entities, bad_files = read_koda_history_day(r_history, 500)
# Out:
# 20:03:22 | INFO | Batch 1–500 / 6031 (8.3%)
# Nb fichiers .pb: 6031
# 20:03:24 | INFO | Batch 501–1000 / 6031 (16.6%)
# 20:03:26 | INFO | Batch 1001–1500 / 6031 (24.9%)
# 20:03:28 | INFO | Batch 1501–2000 / 6031 (33.2%)
# 20:03:32 | INFO | Batch 2001–2500 / 6031 (41.5%)
# 20:03:37 | INFO | Batch 2501–3000 / 6031 (49.7%)
# 20:03:45 | INFO | Batch 3001–3500 / 6031 (58.0%)
# 20:03:54 | INFO | Batch 3501–4000 / 6031 (66.3%)
# 20:04:07 | INFO | Batch 4001–4500 / 6031 (74.6%)
# 20:04:19 | INFO | Batch 4501–5000 / 6031 (82.9%)
# 20:04:28 | INFO | Batch 5001–5500 / 6031 (91.2%)
# 20:04:39 | INFO | Batch 5501–6000 / 6031 (99.5%)
# 20:04:48 | INFO | Batch 6001–6031 / 6031 (100.0%)
# ✅ Total entités enregistrées: 3113034
# ⚠️ Fichiers ignorés: 0
# Exemples: []

# %%
for e in history_entities[:200]:
    print(e)
# Out:
# id: "14010516897425752"
# trip_update {
#   trip {
#     trip_id: "14010000685561305"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "9031001003003885"
#   }
#   stop_time_update {
#     stop_sequence: 1
#     stop_id: "9022001041441002"
#     arrival {
#       delay: -131
#       time: 1741983709
#       uncertainty: 0
#     }
#     departure {
#       delay: 9018
#       time: 1741992858
#       uncertainty: 0
#     }
#   }
#   timestamp: 1741992858
# }
#
# id: "14010516479723124"
# trip_update {
#   trip {
#     trip_id: "14010000668271329"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "9031001004302576"
#   }
#   stop_time_update {
#     stop_sequence: 25
#     stop_id: "9022001006071004"
#     arrival {
#       delay: -65
#       time: 1741992535
#       uncertainty: 0
#     }
#     departure {
#       delay: 9
#       time: 1741992609
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 26
#     stop_id: "9022001006081002"
#     arrival {
#       delay: -66
#       time: 1741992834
#       uncertainty: 0
#     }
#     departure {
#       delay: 31
#       time: 1741992931
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 27
#     stop_id: "9022001006091002"
#     arrival {
#       delay: -30
#       time: 1741993170
#       uncertainty: 0
#     }
#     departure {
#       delay: 0
#       time: 1741993200
#     }
#   }
#   stop_time_update {
#     stop_sequence: 28
#     stop_id: "9022001006101001"
#     arrival {
#       delay: 0
#       time: 1741993560
#     }
#     departure {
#       delay: 0
#       time: 1741993560
#     }
#   }
#   timestamp: 1741993168
# }
#
# id: "14010516479452587"
# trip_update {
#   trip {
#     trip_id: "14010000668242789"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "9031001004002276"
#   }
#   stop_time_update {
#     stop_sequence: 24
#     stop_id: "9022001005006001"
#     arrival {
#       delay: -2
#       time: 1741992898
#       uncertainty: 0
#     }
#     departure {
#       delay: 67
#       time: 1741992967
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 25
#     stop_id: "9022001005007002"
#     arrival {
#       delay: 0
#       time: 1741993440
#     }
#     departure {
#       delay: 0
#       time: 1741993440
#     }
#   }
#   timestamp: 1741992998
# }
#
# id: "14010516477887795"
# trip_update {
#   trip {
#     trip_id: "14010000668271040"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "9031001004302574"
#   }
#   stop_time_update {
#     stop_sequence: 20
#     stop_id: "9022001006101001"
#     arrival {
#       delay: 1368
#       time: 1741993128
#       uncertainty: 0
#     }
#     departure {
#       delay: 1368
#       time: 1741993128
#     }
#   }
#   timestamp: 1741993108
# }
#
# id: "14010516479454423"
# trip_update {
#   trip {
#     trip_id: "14010000668242824"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "9031001004002277"
#   }
#   stop_time_update {
#     stop_sequence: 21
#     stop_id: "9022001005191001"
#     arrival {
#       delay: -58
#       time: 1741992542
#       uncertainty: 0
#     }
#     departure {
#       delay: 21
#       time: 1741992621
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 22
#     stop_id: "9022001005201001"
#     arrival {
#       delay: -78
#       time: 1741992822
#       uncertainty: 0
#     }
#     departure {
#       delay: 7
#       time: 1741992907
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 23
#     stop_id: "9022001005211001"
#     arrival {
#       delay: -78
#       time: 1741993122
#       uncertainty: 0
#     }
#     departure {
#       delay: 0
#       time: 1741993200
#     }
#   }
#   stop_time_update {
#     stop_sequence: 24
#     stop_id: "9022001005221005"
#     arrival {
#       delay: 0
#       time: 1741993320
#     }
#     departure {
#       delay: 0
#       time: 1741993500
#     }
#   }
#   stop_time_update {
#     stop_sequence: 25
#     stop_id: "9022001005231004"
#     arrival {
#       delay: 0
#       time: 1741993740
#     }
#     departure {
#       delay: 0
#       time: 1741993740
#     }
#   }
#   timestamp: 1741993098
# }
#
# id: "14010516478911270"
# trip_update {
#   trip {
#     trip_id: "14010000656735748"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "9031001004102977"
#   }
#   stop_time_update {
#     stop_sequence: 23
#     stop_id: "9022001005221005"
#     arrival {
#       delay: 56
#       time: 1741992476
#       uncertainty: 0
#     }
#     departure {
#       delay: 11
#       time: 1741992611
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 24
#     stop_id: "9022001005231002"
#     arrival {
#       delay: -122
#       time: 1741992718
#       uncertainty: 0
#     }
#     departure {
#       delay: 0
#       time: 1741992840
#     }
#   }
#   timestamp: 1741992707
# }
#
# id: "14010516478909457"
# trip_update {
#   trip {
#     trip_id: "14010000668257205"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "9031001004102976"
#   }
#   stop_time_update {
#     stop_sequence: 22
#     stop_id: "9022001005101002"
#     arrival {
#       delay: -44
#       time: 1741992616
#       uncertainty: 0
#     }
#     departure {
#       delay: 45
#       time: 1741992705
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 23
#     stop_id: "9022001005111002"
#     arrival {
#       delay: -37
#       time: 1741992923
#       uncertainty: 0
#     }
#     departure {
#       delay: 55
#       time: 1741993015
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 24
#     stop_id: "9022001005121002"
#     arrival {
#       delay: 0
#       time: 1741993200
#     }
#     departure {
#       delay: 0
#       time: 1741993200
#     }
#   }
#   timestamp: 1741993038
# }
#
# id: "14010516701138057"
# trip_update {
#   trip {
#     trip_id: "14010000673650562"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "9031001003007242"
#   }
#   stop_time_update {
#     stop_sequence: 56
#     stop_id: "9022001080389001"
#     arrival {
#       delay: 354
#       time: 1741992683
#       uncertainty: 0
#     }
#     departure {
#       delay: 366
#       time: 1741992695
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 57
#     stop_id: "9022001080391001"
#     arrival {
#       delay: 380
#       time: 1741992746
#       uncertainty: 0
#     }
#     departure {
#       delay: 380
#       time: 1741992746
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 58
#     stop_id: "9022001080393001"
#     arrival {
#       delay: 375
#       time: 1741992778
#       uncertainty: 0
#     }
#     departure {
#       delay: 375
#       time: 1741992778
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 59
#     stop_id: "9022001080395001"
#     arrival {
#       delay: 368
#       time: 1741992810
#       uncertainty: 0
#     }
#     departure {
#       delay: 368
#       time: 1741992810
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 60
#     stop_id: "9022001080397001"
#     arrival {
#       delay: 373
#       time: 1741992863
#       uncertainty: 0
#     }
#     departure {
#       delay: 373
#       time: 1741992863
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 61
#     stop_id: "9022001080399001"
#     arrival {
#       delay: 384
#       time: 1741992935
#       uncertainty: 0
#     }
#     departure {
#       delay: 384
#       time: 1741992935
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 62
#     stop_id: "9022001080401001"
#     arrival {
#       delay: 381
#       time: 1741992996
#       uncertainty: 0
#     }
#     departure {
#       delay: 381
#       time: 1741992996
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 63
#     stop_id: "9022001080185001"
#     arrival {
#       delay: 385
#       time: 1741993088
#       uncertainty: 0
#     }
#     departure {
#       delay: 385
#       time: 1741993088
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 64
#     stop_id: "9022001080187001"
#     arrival {
#       delay: 374
#       time: 1741993128
#       uncertainty: 0
#     }
#     departure {
#       delay: 374
#       time: 1741993128
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 65
#     stop_id: "9022001080011001"
#     arrival {
#       delay: 349
#       time: 1741993171
#     }
#     departure {
#       delay: 352
#       time: 1741993174
#     }
#   }
#   stop_time_update {
#     stop_sequence: 66
#     stop_id: "9022001080013001"
#     arrival {
#       delay: 338
#       time: 1741993216
#     }
#     departure {
#       delay: 350
#       time: 1741993228
#     }
#   }
#   stop_time_update {
#     stop_sequence: 67
#     stop_id: "9022001080015005"
#     arrival {
#       delay: 257
#       time: 1741993277
#     }
#     departure {
#       delay: 321
#       time: 1741993341
#     }
#   }
#   stop_time_update {
#     stop_sequence: 68
#     stop_id: "9022001080211001"
#     arrival {
#       delay: 326
#       time: 1741993399
#     }
#     departure {
#       delay: 333
#       time: 1741993406
#     }
#   }
#   stop_time_update {
#     stop_sequence: 69
#     stop_id: "9022001080213001"
#     arrival {
#       delay: 334
#       time: 1741993478
#     }
#     departure {
#       delay: 334
#       time: 1741993478
#     }
#   }
#   stop_time_update {
#     stop_sequence: 70
#     stop_id: "9022001080071001"
#     arrival {
#       delay: 348
#       time: 1741993524
#     }
#     departure {
#       delay: 352
#       time: 1741993528
#     }
#   }
#   stop_time_update {
#     stop_sequence: 71
#     stop_id: "9022001080215001"
#     arrival {
#       delay: 312
#       time: 1741993572
#     }
#     departure {
#       delay: 313
#       time: 1741993573
#     }
#   }
#   stop_time_update {
#     stop_sequence: 72
#     stop_id: "9022001080217001"
#     arrival {
#       delay: 312
#       time: 1741993628
#     }
#     departure {
#       delay: 317
#       time: 1741993633
#     }
#   }
#   stop_time_update {
#     stop_sequence: 73
#     stop_id: "9022001080219001"
#     arrival {
#       delay: 290
#       time: 1741993665
#     }
#     departure {
#       delay: 295
#       time: 1741993670
#     }
#   }
#   stop_time_update {
#     stop_sequence: 74
#     stop_id: "9022001080061001"
#     arrival {
#       delay: 306
#       time: 1741993749
#     }
#     departure {
#       delay: 311
#       time: 1741993754
#     }
#   }
#   stop_time_update {
#     stop_sequence: 75
#     stop_id: "9022001080063001"
#     arrival {
#       delay: 283
#       time: 1741993780
#     }
#     departure {
#       delay: 283
#       time: 1741993780
#     }
#   }
#   stop_time_update {
#     stop_sequence: 76
#     stop_id: "9022001080065001"
#     arrival {
#       delay: 289
#       time: 1741993849
#     }
#     departure {
#       delay: 292
#       time: 1741993852
#     }
#   }
#   stop_time_update {
#     stop_sequence: 77
#     stop_id: "9022001080067002"
#     arrival {
#       delay: 248
#       time: 1741993868
#     }
#     departure {
#       delay: 248
#       time: 1741993868
#     }
#   }
#   stop_time_update {
#     stop_sequence: 78
#     stop_id: "9022001080069001"
#     arrival {
#       delay: 231
#       time: 1741993884
#     }
#     departure {
#       delay: 234
#       time: 1741993887
#     }
#   }
#   stop_time_update {
#     stop_sequence: 79
#     stop_id: "9022001080249001"
#     arrival {
#       delay: 220
#       time: 1741993913
#     }
#     departure {
#       delay: 221
#       time: 1741993914
#     }
#   }
#   stop_time_update {
#     stop_sequence: 80
#     stop_id: "9022001080253001"
#     arrival {
#       delay: 239
#       time: 1741993989
#     }
#     departure {
#       delay: 240
#       time: 1741993990
#     }
#   }
#   stop_time_update {
#     stop_sequence: 81
#     stop_id: "9022001080255001"
#     arrival {
#       delay: 286
#       time: 1741994073
#     }
#     departure {
#       delay: 286
#       time: 1741994073
#     }
#   }
#   stop_time_update {
#     stop_sequence: 82
#     stop_id: "9022001080267001"
#     arrival {
#       delay: 290
#       time: 1741994150
#     }
#     departure {
#       delay: 294
#       time: 1741994154
#     }
#   }
#   stop_time_update {
#     stop_sequence: 83
#     stop_id: "9022001080269001"
#     arrival {
#       delay: 313
#       time: 1741994214
#     }
#     departure {
#       delay: 315
#       time: 1741994216
#     }
#   }
#   stop_time_update {
#     stop_sequence: 84
#     stop_id: "9022001080289001"
#     arrival {
#       delay: 322
#       time: 1741994252
#     }
#     departure {
#       delay: 327
#       time: 1741994257
#     }
#   }
#   stop_time_update {
#     stop_sequence: 85
#     stop_id: "9022001080271001"
#     arrival {
#       delay: 351
#       time: 1741994331
#     }
#     departure {
#       delay: 358
#       time: 1741994338
#     }
#   }
#   stop_time_update {
#     stop_sequence: 86
#     stop_id: "9022001080273001"
#     arrival {
#       delay: 326
#       time: 1741994418
#     }
#     departure {
#       delay: 326
#       time: 1741994418
#     }
#   }
#   stop_time_update {
#     stop_sequence: 87
#     stop_id: "9022001080275001"
#     arrival {
#       delay: 311
#       time: 1741994466
#     }
#     departure {
#       delay: 312
#       time: 1741994467
#     }
#   }
#   stop_time_update {
#     stop_sequence: 88
#     stop_id: "9022001080277001"
#     arrival {
#       delay: 294
#       time: 1741994516
#     }
#     departure {
#       delay: 295
#       time: 1741994517
#     }
#   }
#   stop_time_update {
#     stop_sequence: 89
#     stop_id: "9022001080279001"
#     arrival {
#       delay: 271
#       time: 1741994543
#     }
#     departure {
#       delay: 271
#       time: 1741994543
#     }
#   }
#   stop_time_update {
#     stop_sequence: 90
#     stop_id: "9022001080287001"
#     arrival {
#       delay: 253
#       time: 1741994586
#     }
#     departure {
#       delay: 256
#       time: 1741994589
#     }
#   }
#   stop_time_update {
#     stop_sequence: 91
#     stop_id: "9022001080281001"
#     arrival {
#       delay: 252
#       time: 1741994624
#     }
#     departure {
#       delay: 255
#       time: 1741994627
#     }
#   }
#   stop_time_update {
#     stop_sequence: 92
#     stop_id: "9022001080283002"
#     arrival {
#       delay: 198
#       time: 1741994658
#     }
#     departure {
#       delay: 198
#       time: 1741994658
#     }
#   }
#   timestamp: 1741993174
# }
#
# id: "14010516423127330"
# trip_update {
#   trip {
#     trip_id: "14010000668734586"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "9031001008000623"
#   }
#   stop_time_update {
#     stop_sequence: 10
#     stop_id: "9022001008059001"
#     arrival {
#       delay: -28
#       time: 1741993052
#       uncertainty: 0
#     }
#     departure {
#       delay: 42
#       time: 1741993122
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 11
#     stop_id: "9022001008041001"
#     arrival {
#       delay: -370
#       time: 1741993730
#     }
#     departure {
#       delay: -370
#       time: 1741993730
#     }
#   }
#   timestamp: 1741993186
# }
#
# id: "14010516477504987"
# trip_update {
#   trip {
#     trip_id: "14010000668276396"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "9031001004302877"
#   }
#   stop_time_update {
#     stop_sequence: 17
#     stop_id: "9022001006161001"
#     arrival {
#       delay: -43
#       time: 1741992617
#       uncertainty: 0
#     }
#     departure {
#       delay: 33
#       time: 1741992693
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 18
#     stop_id: "9022001006171003"
#     arrival {
#       delay: -48
#       time: 1741992792
#       uncertainty: 0
#     }
#     departure {
#       delay: 0
#       time: 1741992840
#     }
#   }
#   timestamp: 1741992778
# }
#
# id: "14010516479456259"
# trip_update {
#   trip {
#     trip_id: "14010000668242896"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "9031001004002278"
#   }
#   stop_time_update {
#     stop_sequence: 17
#     stop_id: "9022001005051002"
#     arrival {
#       delay: -33
#       time: 1741992627
#       uncertainty: 0
#     }
#     departure {
#       delay: 30
#       time: 1741992690
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 18
#     stop_id: "9022001005061002"
#     arrival {
#       delay: -56
#       time: 1741992784
#       uncertainty: 0
#     }
#     departure {
#       delay: 6
#       time: 1741992846
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 19
#     stop_id: "9022001005071002"
#     arrival {
#       delay: -117
#       time: 1741992903
#       uncertainty: 0
#     }
#     departure {
#       delay: -8
#       time: 1741993012
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 20
#     stop_id: "9022001005081002"
#     arrival {
#       delay: -23
#       time: 1741993117
#       uncertainty: 0
#     }
#     departure {
#       delay: 34
#       time: 1741993174
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 21
#     stop_id: "9022001005091002"
#     arrival {
#       delay: 0
#       time: 1741993320
#     }
#     departure {
#       delay: 0
#       time: 1741993320
#     }
#   }
#   stop_time_update {
#     stop_sequence: 22
#     stop_id: "9022001005101002"
#     arrival {
#       delay: 0
#       time: 1741993560
#     }
#     departure {
#       delay: 0
#       time: 1741993620
#     }
#   }
#   stop_time_update {
#     stop_sequence: 23
#     stop_id: "9022001005001001"
#     arrival {
#       delay: 0
#       time: 1741994160
#     }
#     departure {
#       delay: 0
#       time: 1741994160
#     }
#   }
#   stop_time_update {
#     stop_sequence: 24
#     stop_id: "9022001005006001"
#     arrival {
#       delay: 0
#       time: 1741994700
#     }
#     departure {
#       delay: 0
#       time: 1741994700
#     }
#   }
#   stop_time_update {
#     stop_sequence: 25
#     stop_id: "9022001005007002"
#     arrival {
#       delay: 0
#       time: 1741995240
#     }
#     departure {
#       delay: 0
#       time: 1741995240
#     }
#   }
#   timestamp: 1741993188
# }
#
# id: "14010516886389050"
# trip_update {
#   trip {
#     trip_id: "14010000669825053"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "9031001004302579"
#   }
#   stop_time_update {
#     stop_sequence: 14
#     stop_id: "9022001006121001"
#     arrival {
#       delay: 29
#       time: 1741992689
#       uncertainty: 0
#     }
#     departure {
#       delay: 97
#       time: 1741992757
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 15
#     stop_id: "9022001006131001"
#     arrival {
#       delay: 56
#       time: 1741992836
#       uncertainty: 0
#     }
#     departure {
#       delay: 138
#       time: 1741992918
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 16
#     stop_id: "9022001006141001"
#     arrival {
#       delay: 91
#       time: 1741993051
#     }
#     departure {
#       delay: 91
#       time: 1741993051
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 17
#     stop_id: "9022001006145001"
#     arrival {
#       delay: 0
#       time: 1741993200
#     }
#     departure {
#       delay: 0
#       time: 1741993200
#     }
#   }
#   stop_time_update {
#     stop_sequence: 18
#     stop_id: "9022001006151001"
#     arrival {
#       delay: 0
#       time: 1741993380
#     }
#     departure {
#       delay: 0
#       time: 1741993380
#     }
#   }
#   stop_time_update {
#     stop_sequence: 19
#     stop_id: "9022001006161001"
#     arrival {
#       delay: 0
#       time: 1741993560
#     }
#     departure {
#       delay: 0
#       time: 1741993560
#     }
#   }
#   stop_time_update {
#     stop_sequence: 20
#     stop_id: "9022001006171003"
#     arrival {
#       delay: 0
#       time: 1741993740
#     }
#     departure {
#       delay: 0
#       time: 1741993920
#     }
#   }
#   stop_time_update {
#     stop_sequence: 21
#     stop_id: "9022001006181002"
#     arrival {
#       delay: 0
#       time: 1741994100
#     }
#     departure {
#       delay: 0
#       time: 1741994100
#     }
#   }
#   stop_time_update {
#     stop_sequence: 22
#     stop_id: "9022001006191001"
#     arrival {
#       delay: 0
#       time: 1741994220
#     }
#     departure {
#       delay: 0
#       time: 1741994220
#     }
#   }
#   stop_time_update {
#     stop_sequence: 23
#     stop_id: "9022001006201002"
#     arrival {
#       delay: 0
#       time: 1741994460
#     }
#     departure {
#       delay: 0
#       time: 1741994460
#     }
#   }
#   stop_time_update {
#     stop_sequence: 24
#     stop_id: "9022001006211001"
#     arrival {
#       delay: 0
#       time: 1741994700
#     }
#     departure {
#       delay: 0
#       time: 1741994700
#     }
#   }
#   stop_time_update {
#     stop_sequence: 25
#     stop_id: "9022001006221002"
#     arrival {
#       delay: 0
#       time: 1741994940
#     }
#     departure {
#       delay: 0
#       time: 1741995000
#     }
#   }
#   stop_time_update {
#     stop_sequence: 26
#     stop_id: "9022001006231001"
#     arrival {
#       delay: 0
#       time: 1741995360
#     }
#     departure {
#       delay: 0
#       time: 1741995360
#     }
#   }
#   stop_time_update {
#     stop_sequence: 27
#     stop_id: "9022001006241001"
#     arrival {
#       delay: 0
#       time: 1741995540
#     }
#     departure {
#       delay: 0
#       time: 1741995540
#     }
#   }
#   stop_time_update {
#     stop_sequence: 28
#     stop_id: "9022001006251002"
#     arrival {
#       delay: 0
#       time: 1741995660
#     }
#     departure {
#       delay: 0
#       time: 1741995660
#     }
#   }
#   timestamp: 1741993073
# }
#
# id: "14010516479458299"
# trip_update {
#   trip {
#     trip_id: "14010000668242967"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "9031001004002279"
#   }
#   stop_time_update {
#     stop_sequence: 13
#     stop_id: "9022001005310002"
#     arrival {
#       delay: -55
#       time: 1741992665
#       uncertainty: 0
#     }
#     departure {
#       delay: 14
#       time: 1741992854
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 14
#     stop_id: "9022001005131004"
#     arrival {
#       delay: -28
#       time: 1741992992
#       uncertainty: 0
#     }
#     departure {
#       delay: 31
#       time: 1741993051
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 15
#     stop_id: "9022001005135001"
#     arrival {
#       delay: -35
#       time: 1741993165
#       uncertainty: 0
#     }
#     departure {
#       delay: 0
#       time: 1741993200
#     }
#   }
#   stop_time_update {
#     stop_sequence: 16
#     stop_id: "9022001005141001"
#     arrival {
#       delay: 0
#       time: 1741993380
#     }
#     departure {
#       delay: 0
#       time: 1741993380
#     }
#   }
#   stop_time_update {
#     stop_sequence: 17
#     stop_id: "9022001005151001"
#     arrival {
#       delay: 0
#       time: 1741993620
#     }
#     departure {
#       delay: 0
#       time: 1741993620
#     }
#   }
#   stop_time_update {
#     stop_sequence: 18
#     stop_id: "9022001005161001"
#     arrival {
#       delay: 0
#       time: 1741993800
#     }
#     departure {
#       delay: 0
#       time: 1741993800
#     }
#   }
#   stop_time_update {
#     stop_sequence: 19
#     stop_id: "9022001005171001"
#     arrival {
#       delay: 0
#       time: 1741993980
#     }
#     departure {
#       delay: 0
#       time: 1741993980
#     }
#   }
#   stop_time_update {
#     stop_sequence: 20
#     stop_id: "9022001005181001"
#     arrival {
#       delay: 0
#       time: 1741994160
#     }
#     departure {
#       delay: 0
#       time: 1741994160
#     }
#   }
#   stop_time_update {
#     stop_sequence: 21
#     stop_id: "9022001005191001"
#     arrival {
#       delay: 0
#       time: 1741994400
#     }
#     departure {
#       delay: 0
#       time: 1741994400
#     }
#   }
#   stop_time_update {
#     stop_sequence: 22
#     stop_id: "9022001005201001"
#     arrival {
#       delay: 0
#       time: 1741994700
#     }
#     departure {
#       delay: 0
#       time: 1741994700
#     }
#   }
#   stop_time_update {
#     stop_sequence: 23
#     stop_id: "9022001005211001"
#     arrival {
#       delay: 0
#       time: 1741995000
#     }
#     departure {
#       delay: 0
#       time: 1741995000
#     }
#   }
#   stop_time_update {
#     stop_sequence: 24
#     stop_id: "9022001005221005"
#     arrival {
#       delay: 0
#       time: 1741995120
#     }
#     departure {
#       delay: 0
#       time: 1741995300
#     }
#   }
#   stop_time_update {
#     stop_sequence: 25
#     stop_id: "9022001005231004"
#     arrival {
#       delay: 0
#       time: 1741995540
#     }
#     departure {
#       delay: 0
#       time: 1741995540
#     }
#   }
#   timestamp: 1741993158
# }
#
# id: "14010516635649299"
# trip_update {
#   trip {
#     trip_id: "14010000672008649"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "9031001003003564"
#   }
#   stop_time_update {
#     stop_sequence: 25
#     stop_id: "9022001051386002"
#     arrival {
#       delay: -65
#       time: 1741992479
#       uncertainty: 0
#     }
#     departure {
#       delay: -40
#       time: 1741992504
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 26
#     stop_id: "9022001051302002"
#     arrival {
#       delay: 0
#       time: 1741992647
#       uncertainty: 0
#     }
#     departure {
#       delay: 0
#       time: 1741992647
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 27
#     stop_id: "9022001051389001"
#     arrival {
#       delay: -16
#       time: 1741992737
#       uncertainty: 0
#     }
#     departure {
#       delay: -16
#       time: 1741992737
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 28
#     stop_id: "9022001054015001"
#     arrival {
#       delay: 33
#       time: 1741992933
#       uncertainty: 0
#     }
#     departure {
#       delay: 33
#       time: 1741992933
#     }
#   }
#   timestamp: 1741992935
# }
#
# id: "14010516423082662"
# trip_update {
#   trip {
#     trip_id: "14010000656145483"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "9031001008000630"
#   }
#   stop_time_update {
#     stop_sequence: 9
#     stop_id: "9022001008007001"
#     arrival {
#       delay: 2
#       time: 1741992842
#       uncertainty: 0
#     }
#     departure {
#       delay: 2
#       time: 1741992842
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 10
#     stop_id: "9022001008041001"
#     arrival {
#       delay: -111
#       time: 1741993209
#     }
#     departure {
#       delay: -111
#       time: 1741993209
#     }
#   }
#   timestamp: 1741993165
# }
#
# id: "14010516478914896"
# trip_update {
#   trip {
#     trip_id: "14010000656736464"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "9031001004102979"
#   }
#   stop_time_update {
#     stop_sequence: 16
#     stop_id: "9022001005151001"
#     arrival {
#       delay: -67
#       time: 1741992653
#       uncertainty: 0
#     }
#     departure {
#       delay: 24
#       time: 1741992744
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 17
#     stop_id: "9022001005161001"
#     arrival {
#       delay: -77
#       time: 1741992823
#       uncertainty: 0
#     }
#     departure {
#       delay: 14
#       time: 1741992914
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 18
#     stop_id: "9022001005171001"
#     arrival {
#       delay: -70
#       time: 1741993010
#       uncertainty: 0
#     }
#     departure {
#       delay: 8
#       time: 1741993088
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 19
#     stop_id: "9022001005181001"
#     arrival {
#       delay: -68
#       time: 1741993192
#       uncertainty: 0
#     }
#     departure {
#       delay: 0
#       time: 1741993260
#     }
#   }
#   stop_time_update {
#     stop_sequence: 20
#     stop_id: "9022001005191001"
#     arrival {
#       delay: 0
#       time: 1741993500
#     }
#     departure {
#       delay: 0
#       time: 1741993500
#     }
#   }
#   stop_time_update {
#     stop_sequence: 21
#     stop_id: "9022001005201001"
#     arrival {
#       delay: 0
#       time: 1741993800
#     }
#     departure {
#       delay: 0
#       time: 1741993800
#     }
#   }
#   stop_time_update {
#     stop_sequence: 22
#     stop_id: "9022001005211001"
#     arrival {
#       delay: 0
#       time: 1741994100
#     }
#     departure {
#       delay: 0
#       time: 1741994100
#     }
#   }
#   stop_time_update {
#     stop_sequence: 23
#     stop_id: "9022001005221005"
#     arrival {
#       delay: 0
#       time: 1741994220
#     }
#     departure {
#       delay: 0
#       time: 1741994400
#     }
#   }
#   stop_time_update {
#     stop_sequence: 24
#     stop_id: "9022001005231002"
#     arrival {
#       delay: 0
#       time: 1741994640
#     }
#     departure {
#       delay: 0
#       time: 1741994640
#     }
#   }
#   timestamp: 1741993188
# }
#
# id: "14010516403338754"
# trip_update {
#   trip {
#     trip_id: "14010000603268833"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "9031001002500184"
#   }
#   stop_time_update {
#     stop_sequence: 26
#     stop_id: "9022001001231001"
#     arrival {
#       delay: 240
#       time: 1741992600
#       uncertainty: 0
#     }
#     departure {
#       delay: 292
#       time: 1741992652
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 27
#     stop_id: "9022001001241001"
#     arrival {
#       delay: 231
#       time: 1741992711
#       uncertainty: 0
#     }
#     departure {
#       delay: 277
#       time: 1741992757
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 28
#     stop_id: "9022001001251001"
#     arrival {
#       delay: 233
#       time: 1741992803
#       uncertainty: 0
#     }
#     departure {
#       delay: 279
#       time: 1741992849
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 29
#     stop_id: "9022001001261001"
#     arrival {
#       delay: 241
#       time: 1741992901
#       uncertainty: 0
#     }
#     departure {
#       delay: 289
#       time: 1741992949
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 30
#     stop_id: "9022001001271001"
#     arrival {
#       delay: 233
#       time: 1741992983
#       uncertainty: 0
#     }
#     departure {
#       delay: 284
#       time: 1741993034
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 31
#     stop_id: "9022001001281001"
#     arrival {
#       delay: 231
#       time: 1741993071
#       uncertainty: 0
#     }
#     departure {
#       delay: 280
#       time: 1741993120
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 32
#     stop_id: "9022001001301001"
#     arrival {
#       delay: 235
#       time: 1741993195
#       uncertainty: 0
#     }
#     departure {
#       delay: 268
#       time: 1741993228
#     }
#   }
#   stop_time_update {
#     stop_sequence: 33
#     stop_id: "9022001001311001"
#     arrival {
#       delay: 254
#       time: 1741993274
#     }
#     departure {
#       delay: 301
#       time: 1741993321
#     }
#   }
#   stop_time_update {
#     stop_sequence: 34
#     stop_id: "9022001001321001"
#     arrival {
#       delay: 254
#       time: 1741993364
#     }
#     departure {
#       delay: 304
#       time: 1741993414
#     }
#   }
#   stop_time_update {
#     stop_sequence: 35
#     stop_id: "9022001001331002"
#     arrival {
#       delay: 238
#       time: 1741993483
#     }
#     departure {
#       delay: 238
#       time: 1741993483
#     }
#   }
#   timestamp: 1741993195
# }
#
# id: "14010516403338825"
# trip_update {
#   trip {
#     trip_id: "14010000594425413"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "9031001002500158"
#   }
#   stop_time_update {
#     stop_sequence: 28
#     stop_id: "9022001001621002"
#     arrival {
#       delay: -40
#       time: 1741992620
#       uncertainty: 0
#     }
#     departure {
#       delay: 7
#       time: 1741992667
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 29
#     stop_id: "9022001001631002"
#     arrival {
#       delay: -41
#       time: 1741992709
#       uncertainty: 0
#     }
#     departure {
#       delay: 9
#       time: 1741992759
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 30
#     stop_id: "9022001001641002"
#     arrival {
#       delay: -22
#       time: 1741992788
#       uncertainty: 0
#     }
#     departure {
#       delay: 28
#       time: 1741992838
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 31
#     stop_id: "9022001001651002"
#     arrival {
#       delay: -33
#       time: 1741992867
#       uncertainty: 0
#     }
#     departure {
#       delay: 14
#       time: 1741992914
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 32
#     stop_id: "9022001001661002"
#     arrival {
#       delay: -9
#       time: 1741992951
#       uncertainty: 0
#     }
#     departure {
#       delay: 42
#       time: 1741993002
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 33
#     stop_id: "9022001001701002"
#     arrival {
#       delay: -28
#       time: 1741993052
#       uncertainty: 0
#     }
#     departure {
#       delay: 38
#       time: 1741993118
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 34
#     stop_id: "9022001001711002"
#     arrival {
#       delay: -19
#       time: 1741993181
#       uncertainty: 0
#     }
#     departure {
#       delay: 0
#       time: 1741993200
#     }
#   }
#   stop_time_update {
#     stop_sequence: 35
#     stop_id: "9022001001721001"
#     arrival {
#       delay: -59
#       time: 1741993291
#     }
#     departure {
#       delay: -59
#       time: 1741993291
#     }
#   }
#   timestamp: 1741993181
# }
#
# id: "14010516477506356"
# trip_update {
#   trip {
#     trip_id: "14010000656770171"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "9031001004302878"
#   }
#   stop_time_update {
#     stop_sequence: 13
#     stop_id: "9022001006031002"
#     arrival {
#       delay: 85
#       time: 1741992625
#       uncertainty: 0
#     }
#     departure {
#       delay: 88
#       time: 1741992688
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 14
#     stop_id: "9022001006041002"
#     arrival {
#       delay: 33
#       time: 1741992873
#       uncertainty: 0
#     }
#     departure {
#       delay: 37
#       time: 1741992937
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 15
#     stop_id: "9022001006051002"
#     arrival {
#       delay: -39
#       time: 1741993041
#       uncertainty: 0
#     }
#     departure {
#       delay: 38
#       time: 1741993118
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 16
#     stop_id: "9022001006061002"
#     arrival {
#       delay: 0
#       time: 1741993260
#     }
#     departure {
#       delay: 0
#       time: 1741993260
#     }
#   }
#   stop_time_update {
#     stop_sequence: 17
#     stop_id: "9022001006071004"
#     arrival {
#       delay: 0
#       time: 1741993500
#     }
#     departure {
#       delay: 0
#       time: 1741993500
#     }
#   }
#   stop_time_update {
#     stop_sequence: 18
#     stop_id: "9022001006081002"
#     arrival {
#       delay: 0
#       time: 1741993800
#     }
#     departure {
#       delay: 0
#       time: 1741993800
#     }
#   }
#   timestamp: 1741993128
# }
#
# id: "14010516478913279"
# trip_update {
#   trip {
#     trip_id: "14010000658164927"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "9031001004102978"
#   }
#   stop_time_update {
#     stop_sequence: 13
#     stop_id: "9022001005310003"
#     arrival {
#       delay: -62
#       time: 1741992598
#       uncertainty: 0
#     }
#     departure {
#       delay: 26
#       time: 1741992806
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 14
#     stop_id: "9022001005320001"
#     arrival {
#       delay: -15
#       time: 1741992885
#       uncertainty: 0
#     }
#     departure {
#       delay: 75
#       time: 1741992975
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 15
#     stop_id: "9022001005031002"
#     arrival {
#       delay: -55
#       time: 1741993145
#       uncertainty: 0
#     }
#     departure {
#       delay: 0
#       time: 1741993200
#     }
#   }
#   stop_time_update {
#     stop_sequence: 16
#     stop_id: "9022001005041002"
#     arrival {
#       delay: 0
#       time: 1741993380
#     }
#     departure {
#       delay: 0
#       time: 1741993380
#     }
#   }
#   stop_time_update {
#     stop_sequence: 17
#     stop_id: "9022001005051002"
#     arrival {
#       delay: 0
#       time: 1741993560
#     }
#     departure {
#       delay: 0
#       time: 1741993560
#     }
#   }
#   stop_time_update {
#     stop_sequence: 18
#     stop_id: "9022001005061002"
#     arrival {
#       delay: 0
#       time: 1741993740
#     }
#     departure {
#       delay: 0
#       time: 1741993740
#     }
#   }
#   stop_time_update {
#     stop_sequence: 19
#     stop_id: "9022001005071002"
#     arrival {
#       delay: 0
#       time: 1741993920
#     }
#     departure {
#       delay: 0
#       time: 1741993920
#     }
#   }
#   stop_time_update {
#     stop_sequence: 20
#     stop_id: "9022001005081002"
#     arrival {
#       delay: 0
#       time: 1741994040
#     }
#     departure {
#       delay: 0
#       time: 1741994040
#     }
#   }
#   stop_time_update {
#     stop_sequence: 21
#     stop_id: "9022001005091002"
#     arrival {
#       delay: 0
#       time: 1741994220
#     }
#     departure {
#       delay: 0
#       time: 1741994220
#     }
#   }
#   stop_time_update {
#     stop_sequence: 22
#     stop_id: "9022001005101002"
#     arrival {
#       delay: 0
#       time: 1741994460
#     }
#     departure {
#       delay: 0
#       time: 1741994460
#     }
#   }
#   stop_time_update {
#     stop_sequence: 23
#     stop_id: "9022001005111002"
#     arrival {
#       delay: 0
#       time: 1741994760
#     }
#     departure {
#       delay: 0
#       time: 1741994760
#     }
#   }
#   stop_time_update {
#     stop_sequence: 24
#     stop_id: "9022001005121001"
#     arrival {
#       delay: 0
#       time: 1741995000
#     }
#     departure {
#       delay: 0
#       time: 1741995000
#     }
#   }
#   timestamp: 1741993128
# }
#
# id: "14010516536201636"
# trip_update {
#   trip {
#     trip_id: "14010000670758027"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "9031001004505599"
#   }
#   stop_time_update {
#     stop_sequence: 10
#     stop_id: "9022001062237001"
#     arrival {
#       delay: 111
#       time: 1741993131
#       uncertainty: 0
#     }
#     departure {
#       delay: 111
#       time: 1741993131
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 11
#     stop_id: "9022001063054004"
#     arrival {
#       delay: 75
#       time: 1741993377
#     }
#     departure {
#       delay: 77
#       time: 1741993379
#     }
#   }
#   stop_time_update {
#     stop_sequence: 12
#     stop_id: "9022001064146001"
#     arrival {
#       delay: 18
#       time: 1741993758
#     }
#     departure {
#       delay: 47
#       time: 1741993787
#     }
#   }
#   stop_time_update {
#     stop_sequence: 13
#     stop_id: "9022001062573001"
#     arrival {
#       delay: 4
#       time: 1741993853
#     }
#     departure {
#       delay: 7
#       time: 1741993856
#     }
#   }
#   stop_time_update {
#     stop_sequence: 14
#     stop_id: "9022001060050013"
#     arrival {
#       delay: -80
#       time: 1741993960
#     }
#     departure {
#       delay: -80
#       time: 1741993960
#     }
#   }
#   timestamp: 1741993192
# }
#
# id: "14010516613285832"
# trip_update {
#   trip {
#     trip_id: "14010000671777961"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "9031001003003067"
#   }
#   stop_time_update {
#     stop_sequence: 37
#     stop_id: "9022001075479002"
#     arrival {
#       delay: 93
#       time: 1741992602
#       uncertainty: 0
#     }
#     departure {
#       delay: 109
#       time: 1741992618
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 38
#     stop_id: "9022001075477002"
#     arrival {
#       delay: 111
#       time: 1741992681
#       uncertainty: 0
#     }
#     departure {
#       delay: 111
#       time: 1741992681
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 39
#     stop_id: "9022001075475002"
#     arrival {
#       delay: 117
#       time: 1741992733
#       uncertainty: 0
#     }
#     departure {
#       delay: 117
#       time: 1741992733
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 40
#     stop_id: "9022001075474004"
#     arrival {
#       delay: 74
#       time: 1741992794
#       uncertainty: 0
#     }
#     departure {
#       delay: 74
#       time: 1741992794
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 41
#     stop_id: "9022001075471002"
#     arrival {
#       delay: 112
#       time: 1741992904
#       uncertainty: 0
#     }
#     departure {
#       delay: 123
#       time: 1741992915
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 42
#     stop_id: "9022001075469002"
#     arrival {
#       delay: 114
#       time: 1741992964
#       uncertainty: 0
#     }
#     departure {
#       delay: 114
#       time: 1741992964
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 43
#     stop_id: "9022001075467002"
#     arrival {
#       delay: 81
#       time: 1741993041
#       uncertainty: 0
#     }
#     departure {
#       delay: 91
#       time: 1741993051
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 44
#     stop_id: "9022001075465002"
#     arrival {
#       delay: 91
#       time: 1741993091
#       uncertainty: 0
#     }
#     departure {
#       delay: 91
#       time: 1741993091
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 45
#     stop_id: "9022001075719002"
#     arrival {
#       delay: 79
#       time: 1741993139
#       uncertainty: 0
#     }
#     departure {
#       delay: 79
#       time: 1741993139
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 46
#     stop_id: "9022001081203002"
#     arrival {
#       delay: 24
#       time: 1741993251
#     }
#     departure {
#       delay: 24
#       time: 1741993251
#     }
#   }
#   stop_time_update {
#     stop_sequence: 47
#     stop_id: "9022001081201002"
#     arrival {
#       delay: 22
#       time: 1741993294
#     }
#     departure {
#       delay: 23
#       time: 1741993295
#     }
#   }
#   stop_time_update {
#     stop_sequence: 48
#     stop_id: "9022001081199002"
#     arrival {
#       delay: -28
#       time: 1741993352
#     }
#     departure {
#       delay: -28
#       time: 1741993352
#     }
#   }
#   timestamp: 1741993183
# }
#
# id: "14010516875212806"
# trip_update {
#   trip {
#     trip_id: "14010000682361665"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 21
#     stop_id: "9022001007401002"
#     arrival {
#       delay: -43
#       time: 1741992677
#       uncertainty: 0
#     }
#     departure {
#       delay: 13
#       time: 1741992733
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 22
#     stop_id: "9022001006901001"
#     arrival {
#       delay: -85
#       time: 1741992875
#       uncertainty: 0
#     }
#     departure {
#       delay: -15
#       time: 1741992945
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 23
#     stop_id: "9022001006911001"
#     arrival {
#       delay: -166
#       time: 1741993094
#       uncertainty: 0
#     }
#     departure {
#       delay: -166
#       time: 1741993094
#     }
#   }
#   timestamp: 1741993094
# }
#
# id: "14010516461747105"
# trip_update {
#   trip {
#     trip_id: "14010000669278393"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 17
#     stop_id: "9022001007171002"
#     arrival {
#       delay: 22
#       time: 1741992622
#     }
#     departure {
#       delay: 22
#       time: 1741992622
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 18
#     stop_id: "9022001006661002"
#     arrival {
#       delay: 6
#       time: 1741992666
#     }
#     departure {
#       delay: 6
#       time: 1741992666
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 19
#     stop_id: "9022001006651003"
#     arrival {
#       delay: -20
#       time: 1741992700
#       uncertainty: 0
#     }
#     departure {
#       delay: 23
#       time: 1741992743
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 20
#     stop_id: "9022001007141002"
#     arrival {
#       delay: -42
#       time: 1741992798
#       uncertainty: 0
#     }
#     departure {
#       delay: 13
#       time: 1741992853
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 21
#     stop_id: "9022001007131002"
#     arrival {
#       delay: -37
#       time: 1741992863
#     }
#     departure {
#       delay: -37
#       time: 1741992863
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 22
#     stop_id: "9022001007111002"
#     arrival {
#       delay: -19
#       time: 1741993001
#       uncertainty: 0
#     }
#     departure {
#       delay: 20
#       time: 1741993040
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 23
#     stop_id: "9022001006601003"
#     arrival {
#       delay: -86
#       time: 1741993174
#       uncertainty: 0
#     }
#     departure {
#       delay: -78
#       time: 1741993182
#       uncertainty: 0
#     }
#   }
#   timestamp: 1741993182
# }
#
# id: "14010516491707706"
# trip_update {
#   trip {
#     trip_id: "14010000624459408"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "9031001003003496"
#   }
#   stop_time_update {
#     stop_sequence: 13
#     stop_id: "9022001075833001"
#     arrival {
#       delay: 1167
#       time: 1741993167
#     }
#     departure {
#       delay: 1167
#       time: 1741993167
#     }
#   }
#   timestamp: 1741993188
# }
#
# id: "14010516655374164"
# trip_update {
#   trip {
#     trip_id: "14010000672917661"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "9031001001506955"
#   }
#   stop_time_update {
#     stop_sequence: 21
#     stop_id: "9022001015313001"
#     arrival {
#       delay: 195
#       time: 1741992624
#       uncertainty: 0
#     }
#     departure {
#       delay: 195
#       time: 1741992624
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 22
#     stop_id: "9022001015315001"
#     arrival {
#       delay: 203
#       time: 1741992718
#       uncertainty: 0
#     }
#     departure {
#       delay: 203
#       time: 1741992718
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 23
#     stop_id: "9022001015317001"
#     arrival {
#       delay: 165
#       time: 1741992760
#       uncertainty: 0
#     }
#     departure {
#       delay: 165
#       time: 1741992760
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 24
#     stop_id: "9022001015319001"
#     arrival {
#       delay: 140
#       time: 1741992848
#       uncertainty: 0
#     }
#     departure {
#       delay: 140
#       time: 1741992848
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 25
#     stop_id: "9022001015321001"
#     arrival {
#       delay: 136
#       time: 1741992891
#       uncertainty: 0
#     }
#     departure {
#       delay: 136
#       time: 1741992891
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 26
#     stop_id: "9022001015323001"
#     arrival {
#       delay: 60
#       time: 1741992960
#       uncertainty: 0
#     }
#     departure {
#       delay: 72
#       time: 1741992972
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 27
#     stop_id: "9022001015325001"
#     arrival {
#       delay: 5
#       time: 1741993025
#       uncertainty: 0
#     }
#     departure {
#       delay: 16
#       time: 1741993036
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 28
#     stop_id: "9022001015327001"
#     arrival {
#       delay: 30
#       time: 1741993077
#       uncertainty: 0
#     }
#     departure {
#       delay: 42
#       time: 1741993089
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 29
#     stop_id: "9022001015323002"
#     arrival {
#       delay: 62
#       time: 1741993202
#     }
#     departure {
#       delay: 74
#       time: 1741993214
#     }
#   }
#   stop_time_update {
#     stop_sequence: 30
#     stop_id: "9022001015321003"
#     arrival {
#       delay: 74
#       time: 1741993247
#     }
#     departure {
#       delay: 74
#       time: 1741993247
#     }
#   }
#   stop_time_update {
#     stop_sequence: 31
#     stop_id: "9022001015703001"
#     arrival {
#       delay: 62
#       time: 1741993288
#     }
#     departure {
#       delay: 62
#       time: 1741993288
#     }
#   }
#   stop_time_update {
#     stop_sequence: 32
#     stop_id: "9022001015705001"
#     arrival {
#       delay: 7
#       time: 1741993342
#     }
#     departure {
#       delay: 7
#       time: 1741993342
#     }
#   }
#   stop_time_update {
#     stop_sequence: 33
#     stop_id: "9022001015707001"
#     arrival {
#       delay: -17
#       time: 1741993402
#     }
#     departure {
#       delay: 13
#       time: 1741993432
#     }
#   }
#   stop_time_update {
#     stop_sequence: 34
#     stop_id: "9022001015709001"
#     arrival {
#       delay: 2
#       time: 1741993481
#     }
#     departure {
#       delay: 3
#       time: 1741993482
#     }
#   }
#   stop_time_update {
#     stop_sequence: 35
#     stop_id: "9022001015711001"
#     arrival {
#       delay: -5
#       time: 1741993540
#     }
#     departure {
#       delay: -2
#       time: 1741993543
#     }
#   }
#   stop_time_update {
#     stop_sequence: 36
#     stop_id: "9022001015713001"
#     arrival {
#       delay: -5
#       time: 1741993589
#     }
#     departure {
#       delay: -5
#       time: 1741993589
#     }
#   }
#   stop_time_update {
#     stop_sequence: 37
#     stop_id: "9022001015672002"
#     arrival {
#       delay: -42
#       time: 1741993638
#     }
#     departure {
#       delay: 0
#       time: 1741993680
#     }
#   }
#   stop_time_update {
#     stop_sequence: 38
#     stop_id: "9022001015803001"
#     arrival {
#       delay: -62
#       time: 1741993761
#     }
#     departure {
#       delay: -62
#       time: 1741993761
#     }
#   }
#   stop_time_update {
#     stop_sequence: 39
#     stop_id: "9022001015805001"
#     arrival {
#       delay: -93
#       time: 1741993823
#     }
#     departure {
#       delay: -90
#       time: 1741993826
#     }
#   }
#   stop_time_update {
#     stop_sequence: 40
#     stop_id: "9022001015807001"
#     arrival {
#       delay: -105
#       time: 1741993863
#     }
#     departure {
#       delay: -105
#       time: 1741993863
#     }
#   }
#   stop_time_update {
# ...
#     arrival {
#       delay: 164
#       time: 1741993462
#     }
#     departure {
#       delay: 165
#       time: 1741993463
#     }
#   }
#   stop_time_update {
#     stop_sequence: 23
#     stop_id: "9022001080217002"
#     arrival {
#       delay: 150
#       time: 1741993503
#     }
#     departure {
#       delay: 153
#       time: 1741993506
#     }
#   }
#   stop_time_update {
#     stop_sequence: 24
#     stop_id: "9022001080215002"
#     arrival {
#       delay: 94
#       time: 1741993534
#     }
#     departure {
#       delay: 101
#       time: 1741993541
#     }
#   }
#   stop_time_update {
#     stop_sequence: 25
#     stop_id: "9022001080071002"
#     arrival {
#       delay: 110
#       time: 1741993599
#     }
#     departure {
#       delay: 112
#       time: 1741993601
#     }
#   }
#   stop_time_update {
#     stop_sequence: 26
#     stop_id: "9022001080213002"
#     arrival {
#       delay: 65
#       time: 1741993639
#     }
#     departure {
#       delay: 65
#       time: 1741993639
#     }
#   }
#   stop_time_update {
#     stop_sequence: 27
#     stop_id: "9022001080211002"
#     arrival {
#       delay: 105
#       time: 1741993787
#     }
#     departure {
#       delay: 108
#       time: 1741993790
#     }
#   }
#   stop_time_update {
#     stop_sequence: 28
#     stop_id: "9022001080015008"
#     arrival {
#       delay: 46
#       time: 1741993846
#     }
#     departure {
#       delay: 97
#       time: 1741993897
#     }
#   }
#   stop_time_update {
#     stop_sequence: 29
#     stop_id: "9022001080013002"
#     arrival {
#       delay: 102
#       time: 1741993938
#     }
#     departure {
#       delay: 107
#       time: 1741993943
#     }
#   }
#   stop_time_update {
#     stop_sequence: 30
#     stop_id: "9022001080011002"
#     arrival {
#       delay: 104
#       time: 1741994013
#     }
#     departure {
#       delay: 109
#       time: 1741994018
#     }
#   }
#   stop_time_update {
#     stop_sequence: 31
#     stop_id: "9022001080187002"
#     arrival {
#       delay: 121
#       time: 1741994085
#     }
#     departure {
#       delay: 124
#       time: 1741994088
#     }
#   }
#   stop_time_update {
#     stop_sequence: 32
#     stop_id: "9022001080185002"
#     arrival {
#       delay: 116
#       time: 1741994124
#     }
#     departure {
#       delay: 119
#       time: 1741994127
#     }
#   }
#   stop_time_update {
#     stop_sequence: 33
#     stop_id: "9022001080401002"
#     arrival {
#       delay: 100
#       time: 1741994179
#     }
#     departure {
#       delay: 103
#       time: 1741994182
#     }
#   }
#   stop_time_update {
#     stop_sequence: 34
#     stop_id: "9022001080399002"
#     arrival {
#       delay: 104
#       time: 1741994255
#     }
#     departure {
#       delay: 109
#       time: 1741994260
#     }
#   }
#   stop_time_update {
#     stop_sequence: 35
#     stop_id: "9022001080397002"
#     arrival {
#       delay: 106
#       time: 1741994306
#     }
#     departure {
#       delay: 107
#       time: 1741994307
#     }
#   }
#   stop_time_update {
#     stop_sequence: 36
#     stop_id: "9022001080395002"
#     arrival {
#       delay: 117
#       time: 1741994363
#     }
#     departure {
#       delay: 120
#       time: 1741994366
#     }
#   }
#   stop_time_update {
#     stop_sequence: 37
#     stop_id: "9022001080393002"
#     arrival {
#       delay: 110
#       time: 1741994407
#     }
#     departure {
#       delay: 110
#       time: 1741994407
#     }
#   }
#   stop_time_update {
#     stop_sequence: 38
#     stop_id: "9022001080391002"
#     arrival {
#       delay: 134
#       time: 1741994454
#     }
#     departure {
#       delay: 135
#       time: 1741994455
#     }
#   }
#   stop_time_update {
#     stop_sequence: 39
#     stop_id: "9022001080389002"
#     arrival {
#       delay: 112
#       time: 1741994466
#     }
#     departure {
#       delay: 114
#       time: 1741994468
#     }
#   }
#   stop_time_update {
#     stop_sequence: 40
#     stop_id: "9022001080385002"
#     arrival {
#       delay: 117
#       time: 1741994530
#     }
#     departure {
#       delay: 121
#       time: 1741994534
#     }
#   }
#   stop_time_update {
#     stop_sequence: 41
#     stop_id: "9022001080383002"
#     arrival {
#       delay: 122
#       time: 1741994599
#     }
#     departure {
#       delay: 124
#       time: 1741994601
#     }
#   }
#   stop_time_update {
#     stop_sequence: 42
#     stop_id: "9022001080349002"
#     arrival {
#       delay: 159
#       time: 1741994713
#     }
#     departure {
#       delay: 164
#       time: 1741994718
#     }
#   }
#   stop_time_update {
#     stop_sequence: 43
#     stop_id: "9022001080092005"
#     arrival {
#       delay: 96
#       time: 1741994796
#     }
#     departure {
#       delay: 59
#       time: 1741994819
#     }
#   }
#   stop_time_update {
#     stop_sequence: 44
#     stop_id: "9022001080348001"
#     arrival {
#       delay: 117
#       time: 1741994929
#     }
#     departure {
#       delay: 117
#       time: 1741994929
#     }
#   }
#   stop_time_update {
#     stop_sequence: 45
#     stop_id: "9022001080372001"
#     arrival {
#       delay: 112
#       time: 1741994992
#     }
#     departure {
#       delay: 117
#       time: 1741994997
#     }
#   }
#   stop_time_update {
#     stop_sequence: 46
#     stop_id: "9022001080368001"
#     arrival {
#       delay: 110
#       time: 1741995036
#     }
#     departure {
#       delay: 112
#       time: 1741995038
#     }
#   }
#   stop_time_update {
#     stop_sequence: 47
#     stop_id: "9022001080366001"
#     arrival {
#       delay: 98
#       time: 1741995107
#     }
#     departure {
#       delay: 102
#       time: 1741995111
#     }
#   }
#   stop_time_update {
#     stop_sequence: 48
#     stop_id: "9022001080364001"
#     arrival {
#       delay: 95
#       time: 1741995157
#     }
#     departure {
#       delay: 97
#       time: 1741995159
#     }
#   }
#   stop_time_update {
#     stop_sequence: 49
#     stop_id: "9022001080362001"
#     arrival {
#       delay: 98
#       time: 1741995200
#     }
#     departure {
#       delay: 100
#       time: 1741995202
#     }
#   }
#   stop_time_update {
#     stop_sequence: 50
#     stop_id: "9022001080360001"
#     arrival {
#       delay: 99
#       time: 1741995227
#     }
#     departure {
#       delay: 99
#       time: 1741995227
#     }
#   }
#   stop_time_update {
#     stop_sequence: 51
#     stop_id: "9022001080358001"
#     arrival {
#       delay: 84
#       time: 1741995269
#     }
#     departure {
#       delay: 87
#       time: 1741995272
#     }
#   }
#   stop_time_update {
#     stop_sequence: 52
#     stop_id: "9022001080356001"
#     arrival {
#       delay: 79
#       time: 1741995340
#     }
#     departure {
#       delay: 79
#       time: 1741995340
#     }
#   }
#   stop_time_update {
#     stop_sequence: 53
#     stop_id: "9022001080092004"
#     arrival {
#       delay: 3
#       time: 1741995363
#     }
#     departure {
#       delay: 0
#       time: 1741995660
#     }
#   }
#   stop_time_update {
#     stop_sequence: 54
#     stop_id: "9022001080349001"
#     arrival {
#       delay: 14
#       time: 1741995731
#     }
#     departure {
#       delay: 15
#       time: 1741995732
#     }
#   }
#   stop_time_update {
#     stop_sequence: 55
#     stop_id: "9022001080383001"
#     arrival {
#       delay: 18
#       time: 1741995823
#     }
#     departure {
#       delay: 19
#       time: 1741995824
#     }
#   }
#   stop_time_update {
#     stop_sequence: 56
#     stop_id: "9022001080385001"
#     arrival {
#       delay: 29
#       time: 1741995897
#     }
#     departure {
#       delay: 34
#       time: 1741995902
#     }
#   }
#   stop_time_update {
#     stop_sequence: 57
#     stop_id: "9022001080389001"
#     arrival {
#       delay: 34
#       time: 1741995963
#     }
#     departure {
#       delay: 35
#       time: 1741995964
#     }
#   }
#   stop_time_update {
#     stop_sequence: 58
#     stop_id: "9022001080391001"
#     arrival {
#       delay: 41
#       time: 1741996007
#     }
#     departure {
#       delay: 43
#       time: 1741996009
#     }
#   }
#   stop_time_update {
#     stop_sequence: 59
#     stop_id: "9022001080393001"
#     arrival {
#       delay: 41
#       time: 1741996044
#     }
#     departure {
#       delay: 41
#       time: 1741996044
#     }
#   }
#   stop_time_update {
#     stop_sequence: 60
#     stop_id: "9022001080395001"
#     arrival {
#       delay: 55
#       time: 1741996097
#     }
#     departure {
#       delay: 55
#       time: 1741996097
#     }
#   }
#   stop_time_update {
#     stop_sequence: 61
#     stop_id: "9022001080397001"
#     arrival {
#       delay: 30
#       time: 1741996120
#     }
#     departure {
#       delay: 30
#       time: 1741996120
#     }
#   }
#   stop_time_update {
#     stop_sequence: 62
#     stop_id: "9022001080399001"
#     arrival {
#       delay: 30
#       time: 1741996181
#     }
#     departure {
#       delay: 31
#       time: 1741996182
#     }
#   }
#   stop_time_update {
#     stop_sequence: 63
#     stop_id: "9022001080401001"
#     arrival {
#       delay: 16
#       time: 1741996231
#     }
#     departure {
#       delay: 16
#       time: 1741996231
#     }
#   }
#   stop_time_update {
#     stop_sequence: 64
#     stop_id: "9022001080185001"
#     arrival {
#       delay: 10
#       time: 1741996313
#     }
#     departure {
#       delay: 11
#       time: 1741996314
#     }
#   }
#   stop_time_update {
#     stop_sequence: 65
#     stop_id: "9022001080187001"
#     arrival {
#       delay: 20
#       time: 1741996374
#     }
#     departure {
#       delay: 20
#       time: 1741996374
#     }
#   }
#   stop_time_update {
#     stop_sequence: 66
#     stop_id: "9022001080011001"
#     arrival {
#       delay: -19
#       time: 1741996403
#     }
#     departure {
#       delay: -18
#       time: 1741996404
#     }
#   }
#   stop_time_update {
#     stop_sequence: 67
#     stop_id: "9022001080013001"
#     arrival {
#       delay: -22
#       time: 1741996456
#     }
#     departure {
#       delay: -21
#       time: 1741996457
#     }
#   }
#   stop_time_update {
#     stop_sequence: 68
#     stop_id: "9022001080015005"
#     arrival {
#       delay: -111
#       time: 1741996509
#     }
#     departure {
#       delay: 0
#       time: 1741996620
#     }
#   }
#   stop_time_update {
#     stop_sequence: 69
#     stop_id: "9022001080211001"
#     arrival {
#       delay: -10
#       time: 1741996663
#     }
#     departure {
#       delay: -9
#       time: 1741996664
#     }
#   }
#   stop_time_update {
#     stop_sequence: 70
#     stop_id: "9022001080213001"
#     arrival {
#       delay: 0
#       time: 1741996744
#     }
#     departure {
#       delay: 0
#       time: 1741996744
#     }
#   }
#   stop_time_update {
#     stop_sequence: 71
#     stop_id: "9022001080071001"
#     arrival {
#       delay: 23
#       time: 1741996799
#     }
#     departure {
#       delay: 25
#       time: 1741996801
#     }
#   }
#   stop_time_update {
#     stop_sequence: 72
#     stop_id: "9022001080215001"
#     arrival {
#       delay: -32
#       time: 1741996828
#     }
#     departure {
#       delay: -29
#       time: 1741996831
#     }
#   }
#   stop_time_update {
#     stop_sequence: 73
#     stop_id: "9022001080217001"
#     arrival {
#       delay: -21
#       time: 1741996895
#     }
#     departure {
#       delay: -16
#       time: 1741996900
#     }
#   }
#   stop_time_update {
#     stop_sequence: 74
#     stop_id: "9022001080219001"
#     arrival {
#       delay: -33
#       time: 1741996942
#     }
#     departure {
#       delay: -32
#       time: 1741996943
#     }
#   }
#   stop_time_update {
#     stop_sequence: 75
#     stop_id: "9022001080061001"
#     arrival {
#       delay: -40
#       time: 1741997003
#     }
#     departure {
#       delay: -34
#       time: 1741997009
#     }
#   }
#   stop_time_update {
#     stop_sequence: 76
#     stop_id: "9022001080063001"
#     arrival {
#       delay: -50
#       time: 1741997047
#     }
#     departure {
#       delay: -49
#       time: 1741997048
#     }
#   }
#   stop_time_update {
#     stop_sequence: 77
#     stop_id: "9022001080065001"
#     arrival {
#       delay: -75
#       time: 1741997085
#     }
#     departure {
#       delay: 0
#       time: 1741997160
#     }
#   }
#   stop_time_update {
#     stop_sequence: 78
#     stop_id: "9022001080067002"
#     arrival {
#       delay: -44
#       time: 1741997176
#     }
#     departure {
#       delay: -44
#       time: 1741997176
#     }
#   }
#   stop_time_update {
#     stop_sequence: 79
#     stop_id: "9022001080069001"
#     arrival {
#       delay: -51
#       time: 1741997202
#     }
#     departure {
#       delay: -45
#       time: 1741997208
#     }
#   }
#   stop_time_update {
#     stop_sequence: 80
#     stop_id: "9022001080249001"
#     arrival {
#       delay: -37
#       time: 1741997256
#     }
#     departure {
#       delay: -37
#       time: 1741997256
#     }
#   }
#   stop_time_update {
#     stop_sequence: 81
#     stop_id: "9022001080253001"
#     arrival {
#       delay: -21
#       time: 1741997329
#     }
#     departure {
#       delay: -21
#       time: 1741997329
#     }
#   }
#   stop_time_update {
#     stop_sequence: 82
#     stop_id: "9022001080255001"
#     arrival {
#       delay: -8
#       time: 1741997379
#     }
#     departure {
#       delay: -8
#       time: 1741997379
#     }
#   }
#   stop_time_update {
#     stop_sequence: 83
#     stop_id: "9022001080267001"
#     arrival {
#       delay: -5
#       time: 1741997455
#     }
#     departure {
#       delay: 0
#       time: 1741997460
#     }
#   }
#   stop_time_update {
#     stop_sequence: 84
#     stop_id: "9022001080269001"
#     arrival {
#       delay: 12
#       time: 1741997513
#     }
#     departure {
#       delay: 15
#       time: 1741997516
#     }
#   }
#   stop_time_update {
#     stop_sequence: 85
#     stop_id: "9022001080289001"
#     arrival {
#       delay: 21
#       time: 1741997551
#     }
#     departure {
#       delay: 21
#       time: 1741997551
#     }
#   }
#   stop_time_update {
#     stop_sequence: 86
#     stop_id: "9022001080271001"
#     arrival {
#       delay: 28
#       time: 1741997608
#     }
#     departure {
#       delay: 31
#       time: 1741997611
#     }
#   }
#   stop_time_update {
#     stop_sequence: 87
#     stop_id: "9022001080273001"
#     arrival {
#       delay: 15
#       time: 1741997707
#     }
#     departure {
#       delay: 16
#       time: 1741997708
#     }
#   }
#   stop_time_update {
#     stop_sequence: 88
#     stop_id: "9022001080275001"
#     arrival {
#       delay: 0
#       time: 1741997755
#     }
#     departure {
#       delay: 1
#       time: 1741997756
#     }
#   }
#   stop_time_update {
#     stop_sequence: 89
#     stop_id: "9022001080277001"
#     arrival {
#       delay: -13
#       time: 1741997809
#     }
#     departure {
#       delay: -10
#       time: 1741997812
#     }
#   }
#   stop_time_update {
#     stop_sequence: 90
#     stop_id: "9022001080279001"
#     arrival {
#       delay: -31
#       time: 1741997841
#     }
#     departure {
#       delay: -31
#       time: 1741997841
#     }
#   }
#   stop_time_update {
#     stop_sequence: 91
#     stop_id: "9022001080287001"
#     arrival {
#       delay: -47
#       time: 1741997886
#     }
#     departure {
#       delay: -46
#       time: 1741997887
#     }
#   }
#   stop_time_update {
#     stop_sequence: 92
#     stop_id: "9022001080281001"
#     arrival {
#       delay: -74
#       time: 1741997898
#     }
#     departure {
#       delay: -70
#       time: 1741997902
#     }
#   }
#   stop_time_update {
#     stop_sequence: 93
#     stop_id: "9022001080283002"
#     arrival {
#       delay: -113
#       time: 1741997947
#     }
#     departure {
#       delay: -88
#       time: 1741997972
#     }
#   }
#   timestamp: 1741993186
# }
#
# id: "14010516861224569"
# trip_update {
#   trip {
#     trip_id: "14010000681785695"
#     start_date: "20250314"
#     schedule_relationship: SCHEDULED
#   }
#   vehicle {
#     id: "9031001003002491"
#   }
#   stop_time_update {
#     stop_sequence: 7
#     stop_id: "9022001013017004"
#     arrival {
#       delay: 18
#       time: 1741992585
#       uncertainty: 0
#     }
#     departure {
#       delay: 18
#       time: 1741992585
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 8
#     stop_id: "9022001080159002"
#     arrival {
#       delay: 14
#       time: 1741992622
#       uncertainty: 0
#     }
#     departure {
#       delay: 14
#       time: 1741992622
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 9
#     stop_id: "9022001080157002"
#     arrival {
#       delay: 4
#       time: 1741992660
#       uncertainty: 0
#     }
#     departure {
#       delay: 4
#       time: 1741992660
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 10
#     stop_id: "9022001013551004"
#     arrival {
#       delay: 1
#       time: 1741992739
#       uncertainty: 0
#     }
#     departure {
#       delay: 1
#       time: 1741992739
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 11
#     stop_id: "9022001080153004"
#     arrival {
#       delay: 8
#       time: 1741992808
#       uncertainty: 0
#     }
#     departure {
#       delay: 8
#       time: 1741992808
#       uncertainty: 0
#     }
#   }
#   stop_time_update {
#     stop_sequence: 12
#     stop_id: "9022001011725009"
#     arrival {
#       delay: -117
#       time: 1741992963
#       uncertainty: 0
#     }
#     departure {
#       delay: -117
#       time: 1741992963
#     }
#   }
#   timestamp: 1741992966
# }
