# %%
import boto3
import logging
from datetime import datetime, timezone, timedelta
from collections import defaultdict
import random
import gc
import json
import pandas as pd
import os
from sqlalchemy import create_engine
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
AWS_ACCESS_KEY_ID = os.getenv("AWS_ACCESS_KEY_ID")
AWS_SECRET_ACCESS_KEY = os.getenv("AWS_SECRET_ACCESS_KEY")

session = boto3.Session(aws_access_key_id=AWS_ACCESS_KEY_ID, 
                        aws_secret_access_key=AWS_SECRET_ACCESS_KEY)

s3 = session.client("s3")

#bucket = s3.Bucket("jedha-lead-bus-delays") 

array = [
    {"test": "numero", "pringles":"ail"},
    {"test": "ppp", "pringles":"oli"},
    {"test": "ooo", "pringles":"tom"},
]

json_data = json.dumps(array, ensure_ascii=False)

s3.put_object(
    Bucket="jedha-lead-bus-delays",
    Key="transport/data.json",
    Body=json_data.encode("utf-8"),
    ContentType="application/json"
)
# Out:
# {'ResponseMetadata': {'RequestId': 'Q3EGCCZC3KBPG4E2',
#   'HostId': '1+SnCo/QpMI9OfHLwX6J1NmV/fLCi6ZxEk3fnM38hOIiyBx8aAQU461FshsYCoEhlaDI9QrG5vI/HBbfQCp8d1k+6LuIBRXp',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': '1+SnCo/QpMI9OfHLwX6J1NmV/fLCi6ZxEk3fnM38hOIiyBx8aAQU461FshsYCoEhlaDI9QrG5vI/HBbfQCp8d1k+6LuIBRXp',
#    'x-amz-request-id': 'Q3EGCCZC3KBPG4E2',
#    'date': 'Sat, 03 Jan 2026 16:03:47 GMT',
#    'x-amz-server-side-encryption': 'AES256',
#    'etag': '"87def11159e7234eda0e521300ea89c9"',
#    'x-amz-checksum-crc32': 'xR952w==',
#    'x-amz-checksum-type': 'FULL_OBJECT',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 1},
#  'ETag': '"87def11159e7234eda0e521300ea89c9"',
#  'ChecksumCRC32': 'xR952w==',
#  'ChecksumType': 'FULL_OBJECT',
#  'ServerSideEncryption': 'AES256'}
