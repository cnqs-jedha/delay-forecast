# %%
import boto3
import logging
from datetime import datetime, timezone, timedelta
from collections import defaultdict
import random
import gc
import json
import pandas as pd
import os
from sqlalchemy import create_engine
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
AWS_ACCESS_KEY_ID = os.getenv("AWS_ACCESS_KEY_ID")
AWS_SECRET_ACCESS_KEY = os.getenv("AWS_SECRET_ACCESS_KEY")


session = boto3.Session(aws_access_key_id=AWS_ACCESS_KEY_ID, 
                        aws_secret_access_key=AWS_SECRET_ACCESS_KEY)

s3 = session.client("s3")

# s3.put_object(
#     Bucket="jedha-lead-bus-delays",
#     Key="transport/data.json",
#     Body=json_data.encode("utf-8"),
#     ContentType="application/json"
# )
DATE_BEGIN = "2025-01-06"
DATE_END = "2025-01-12"

file_name = f"history_transport_{DATE_BEGIN}-{DATE_END}"
aws_json_key = f"transport/{file_name}.json"
obj = s3.get_object(Bucket="jedha-lead-bus-delays", Key=aws_json_key)
data = json.loads(obj["Body"].read().decode("utf-8"))

print(type(data), len(data))
# Out:
# <class 'list'> 720

# %%
print(data[:200])
# Out:
# [{'timestamp': 1736145316, 'trip_id': '14010000670443665', 'route_id': '9011001054100000', 'direction_id': '1', 'start_date': '20250106', 'vehicle_id': '9031001003003544', 'stop_sequence': 15, 'arrival_time': 1736145814, 'departure_time': 1736145818, 'arrival_delay': 220, 'departure_delay': 224}, {'timestamp': 1736160994, 'trip_id': '14010000644187297', 'route_id': '9011001054100000', 'direction_id': '1', 'start_date': '20250106', 'vehicle_id': '9031001003003512', 'stop_sequence': 31, 'arrival_time': 1736162895, 'departure_time': 1736162899, 'arrival_delay': -53, 'departure_delay': -49}, {'timestamp': 1736180902, 'trip_id': '14010000670450349', 'route_id': '9011001054100000', 'direction_id': '1', 'start_date': '20250106', 'vehicle_id': '9031001003003535', 'stop_sequence': 5, 'arrival_time': 1736181000, 'departure_time': 1736181006, 'arrival_delay': 14, 'departure_delay': 20}, {'timestamp': 1736143587, 'trip_id': '14010000644182649', 'route_id': '9011001054100000', 'direction_id': '0', 'start_date': '20250106', 'vehicle_id': '9031001003003554', 'stop_sequence': 23, 'arrival_time': 1736143495, 'departure_time': 1736143495, 'arrival_delay': 190, 'departure_delay': 190}, {'timestamp': 1736167395, 'trip_id': '14010000670447485', 'route_id': '9011001054100000', 'direction_id': '0', 'start_date': '20250106', 'vehicle_id': '9031001003003509', 'stop_sequence': 18, 'arrival_time': 1736167389, 'departure_time': 1736167389, 'arrival_delay': 189, 'departure_delay': 189}, {'timestamp': 1736184946, 'trip_id': '14010000670451117', 'route_id': '9011001054100000', 'direction_id': '1', 'start_date': '20250106', 'vehicle_id': '9031001003003581', 'stop_sequence': 24, 'arrival_time': 1736185806, 'departure_time': 1736185812, 'arrival_delay': -24, 'departure_delay': -18}, {'timestamp': 1736170537, 'trip_id': '14010000644190271', 'route_id': '9011001054100000', 'direction_id': '1', 'start_date': '20250106', 'vehicle_id': '9031001003003568', 'stop_sequence': 29, 'arrival_time': 1736171827, 'departure_time': 1736171854, 'arrival_delay': 1, 'departure_delay': 28}, {'timestamp': 1736177876, 'trip_id': '14010000644193093', 'route_id': '9011001054100000', 'direction_id': '0', 'start_date': '20250106', 'vehicle_id': '9031001003003535', 'stop_sequence': 29, 'arrival_time': 1736179527, 'departure_time': 1736179740, 'arrival_delay': -213, 'departure_delay': 0}, {'timestamp': 1736167432, 'trip_id': '14010000644162409', 'route_id': '9011001054100000', 'direction_id': '1', 'start_date': '20250106', 'vehicle_id': '9031001003003512', 'stop_sequence': 1, 'arrival_time': 1736167017, 'departure_time': 1736167041, 'arrival_delay': -3, 'departure_delay': -39}, {'timestamp': 1736180015, 'trip_id': '14010000644193949', 'route_id': '9011001054100000', 'direction_id': '1', 'start_date': '20250106', 'vehicle_id': '9031001003003512', 'stop_sequence': 30, 'arrival_time': 1736181823, 'departure_time': 1736181837, 'arrival_delay': 45, 'departure_delay': 59}, {'timestamp': 1736177743, 'trip_id': '14010000670449770', 'route_id': '9011001054100000', 'direction_id': '0', 'start_date': '20250106', 'vehicle_id': '9031001003003512', 'stop_sequence': 13, 'arrival_time': 1736177850, 'departure_time': 1736177857, 'arrival_delay': 238, 'departure_delay': 245}, {'timestamp': 1736152015, 'trip_id': '14010000644184716', 'route_id': '9011001054100000', 'direction_id': '0', 'start_date': '20250106', 'vehicle_id': '9031001003003536', 'stop_sequence': 22, 'arrival_time': 1736153015, 'departure_time': 1736153021, 'arrival_delay': -73, 'departure_delay': -67}, {'timestamp': 1736186501, 'trip_id': '14010000670451117', 'route_id': '9011001054100000', 'direction_id': '1', 'start_date': '20250106', 'vehicle_id': '9031001003003581', 'stop_sequence': 31, 'arrival_time': 1736186116, 'departure_time': 1736186116, 'arrival_delay': -199, 'departure_delay': -199}, {'timestamp': 1736158212, 'trip_id': '14010000644186502', 'route_id': '9011001054100000', 'direction_id': '1', 'start_date': '20250106', 'vehicle_i ...
